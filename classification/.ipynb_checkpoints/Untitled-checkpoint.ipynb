# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('../data/HTRU_2.csv')
data.columns = ['Mean IP', 'Standard deviation IP', 'Excess kurtosis IP', 'Skewness IP',
                'Mean DS', 'Standard deviation DS', 'Excess kurtosis DS', 'Skewness DS',
                'Class']

# %%
data.describe()
# Out:
#             Mean IP  Standard deviation IP  Excess kurtosis IP   Skewness IP  \
# count  17897.000000           17897.000000        17897.000000  17897.000000
# mean     111.078321              46.549021            0.477897      1.770417
# std       25.652705               6.843040            1.064056      6.168058
# min        5.812500              24.772042           -1.876011     -1.791886
# 25%      100.929688              42.375426            0.027108     -0.188528
# 50%      115.078125              46.946435            0.223241      0.198736
# 75%      127.085938              51.022887            0.473349      0.928206
# max      192.617188              98.778911            8.069522     68.101622
#
#             Mean DS  Standard deviation DS  Excess kurtosis DS   Skewness DS  \
# count  17897.000000           17897.000000        17897.000000  17897.000000
# mean      12.614926              26.326918            8.303574    104.859419
# std       29.473637              19.471042            4.506217    106.517270
# min        0.213211               7.370432           -3.139270     -1.976976
# 25%        1.923077              14.437330            5.781485     34.957119
# 50%        2.801839              18.459977            8.433872     83.068996
# 75%        5.464883              28.428152           10.702973    139.310905
# max      223.392141             110.642211           34.539844   1191.000837
#
#              Class
# count  17897.00000
# mean       0.09158
# std        0.28844
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000

# %%
data.head()
# Out:
#       Mean IP  Standard deviation IP  Excess kurtosis IP  Skewness IP  \
# 0  102.507812              58.882430            0.465318    -0.515088
# 1  103.015625              39.341649            0.323328     1.051164
# 2  136.750000              57.178449           -0.068415    -0.636238
# 3   88.726562              40.672225            0.600866     1.123492
# 4   93.570312              46.698114            0.531905     0.416721
#
#     Mean DS  Standard deviation DS  Excess kurtosis DS  Skewness DS  Class
# 0  1.677258              14.860146           10.576487   127.393580      0
# 1  3.121237              21.744669            7.735822    63.171909      0
# 2  3.642977              20.959280            6.896499    53.593661      0
# 3  1.178930              11.468720           14.269573   252.567306      0
# 4  1.636288              14.545074           10.621748   131.394004      0

# %%
x = data.drop('Class', axis = 'columns')
y = data['Class']

# %%
x.describe()
x.columns
# Out:
# Index(['Mean IP', 'Standard deviation IP', 'Excess kurtosis IP', 'Skewness IP',
#        'Mean DS', 'Standard deviation DS', 'Excess kurtosis DS',
#        'Skewness DS'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, stratify = y)

# %%
stablo = DecisionTreeClassifier()
stablo.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# pozajmicemo funkciju crtanja stabla sa casa

def plot_decision_tree(model, feature_names):
    plt.figure(figsize = (40, 20))
    max_depth = 3
    plot_tree(model, class_names = ['0', '1'], feature_names = feature_names, filled = True, max_depth = max_depth)
    plt.title("Stablo odlucivanja dubine {} sa ukupno {} krajnjih cvorova (prikazano je samo prva {} sloja)"
              .format(model.get_depth(), model.get_n_leaves(), max_depth))
    plt.show()

# %%
plt.figure()
plot_decision_tree(stablo, x.columns)
plt.show()

# %%
pd.Series(stablo.feature_importances_, index =x.columns).plot.bar()
plt.title("Znacaj kolona")
plt.show()
# vidimo da je najvise znacaja imala kolona
# koja je prilikom analize sirovih podataka imala najvecu korelaciju sa klasom
# i takodje jedina kojoj je presek unutrasnjih 50 kvantila pozitivne i negativne klase prazan skup

# %%
# funkcija za pravljenje matrice konfucije
def matConf(model, x, y):
    y_pred = model.predict(x)
    return confusion_matrix(y, y_pred)

# %%
sb.heatmap(matConf(stablo, x_train, y_train), annot = True, fmt = 'g')
# Out:
# <Axes: >

# %%
sb.heatmap(matConf(stablo, x_test, y_test), annot = True, fmt = 'g')
# Out:
# <Axes: >
